# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_regression

X, y = make_regression(n_samples = 1_000, 
                       n_features = 10,
                       noise = 2,
                       random_state = 42)
X.shape, y.shape
# Out:
# ((1000, 10), (1000,))

# %%
test_split = 10

X_train, X_test = X[:-test_split, ...], X[-test_split:, ...]
y_train, y_test = y[:-test_split, ...], y[-test_split:, ...]

print(X_train.shape, X_test.shape)
# Out:
# (990, 10) (10, 10)

# %%
from model import Model
from layers.dense import Dense
from layers.activation import ActivationLayer

model = Model(learning_rate = 1e-4)
model.add(Dense(8))
model.add(ActivationLayer('relu'))
model.add(Dense(1))

# %%
epoches = 500
loss = model.fit(X_train, y_train, epoches = epoches)

# %%
plt.plot(range(1, epoches + 1), loss, 'b')
plt.title('LOSS')
plt.xlabel('epochs')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %%
np.hstack([model.predict(X_test), y_test.reshape((-1, 1))])
# Out:
# array([[ 72.7538744 ,  70.74390214],
#        [185.38551684, 184.45212345],
#        [-15.19788151, -12.68000798],
#        [119.29297016, 121.89803657],
#        [292.26768243, 291.02543687],
#        [107.21317318, 106.61093735],
#        [-53.10121841, -53.83146166],
#        [ -4.03720772,  -7.71632493],
#        [-12.78589688, -13.96401218],
#        [-78.21935548, -74.38438616]])
